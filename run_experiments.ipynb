# %%
import itertools

algorithms = ["pi", "vi", "cvi", "c51"] 
envs = ["taxi", "frozenlake"]
seeds = [0, 42, 100]

# %%
# Environment to config mapping
env_config_map = {
    "taxi": {
        "pi": "config/taxi_pi.yaml",
        "vi": "config/taxi_vi.yaml",
        "cvi": "config/taxi_cvi.yaml",
        "c51": "config/taxi_c51.yaml"
    },
    "frozenlake": {
        "pi": "config/frozenlake_pi.yaml",
        "vi": "config/frozenlake_vi.yaml",
        "cvi": "config/frozenlake_cvi.yaml",
        "c51": "config/frozenlake_c51.yaml"
    }
}

# %%
import time

total_experiments = len(algorithms) * len(envs) * len(seeds)
completed = 0
failed = 0

print(f"Starting {total_experiments} experiments...")
print(f"Algorithms: {algorithms}")
print(f"Environments: {envs}")
print(f"Seeds: {seeds}")

start_time = time.time()

for algo, env, seed in itertools.product(algorithms, envs, seeds):
    config_file = env_config_map[env][algo]
    
    run_name = f"{env}_{algo}_seed{seed}"
    tags = [f"algo_{algo}", f"env_{env}", f"seed_{seed}"]
    tags_str = f"\"['{'\',\''.join(tags)}']\""
    
    print(f"\n{'='*60}")
    print(f"🚀 Running: {algo} on {env} with seed {seed}")
    print(f"{'='*60}")
    
    cmd = f"""
    python train.py \
        {config_file} \
        logger.do.online=true \
        logger.project_name=CVI-RL \
        logger.run_name={run_name} \
        logger.tags={tags_str} \
        seed={seed}
    """
    
    cmd = " ".join(cmd.split())
    print(f"Command: {cmd}\n")
    
    try:
        # !{cmd}
        print(f"✅ Completed: {algo} on {env} with seed {seed}")
    except Exception as e:
        print(f"⚠️  WARNING: Experiment failed with error: {e}")
        failed += 1
    
    completed += 1
    print(f"\nProgress: {completed}/{total_experiments} completed ({failed} failed)")
    
    time.sleep(2)
            
elapsed_time = time.time() - start_time
print(f"\n{'='*60}")
print(f"All experiments completed!")
print(f"Total time: {elapsed_time/60:.2f} minutes")
print(f"Successful: {completed - failed}/{total_experiments}")
print(f"Failed: {failed}/{total_experiments}")
print(f"{'='*60}")
# Out:
# Starting 24 experiments...
# Algorithms: ['pi', 'vi', 'cvi', 'c51']
# Environments: ['taxi', 'frozenlake']
# Seeds: [0, 42, 100]
#
# ============================================================
# 🚀 Running: pi on taxi with seed 0
# ============================================================
# Command: python train.py config/taxi_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_pi_seed0 logger.tags="['algo_pi','env_taxi','seed_0']" seed=0
#
# Random seed set to: 0
# Random seed set to: 0
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_165917-s2df513z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed0 13/12-16:59:17
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/s2df513z
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_165917-s2df513z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed0 13/12-16:59:17
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/s2df513z
# W&B logging enabled: CVI-RLW&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:   0%|                                  | 0/50 [00:00<?, ?it/s]
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:55,  1.63s/it]
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:55,  1.63s/it]
# First Evaluation: -99.99990136574544
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 14803.60it/s]
#
# Converged in 17 iterations
# Training time: 26.10s
# Policy saved to saved_policies/pi_taxi_policy.npy
# First Evaluation: -99.99990136574544
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 14803.60it/s]
#
# Converged in 17 iterations
# Training time: 26.10s
# Policy saved to saved_policies/pi_taxi_policy.npy
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.098565816879272
#   converged_iterations: 17
#   expected_initial_state_value: 6.367867097536757
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.367867097536754
#   mc_success_rate: 1.0
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.098565816879272
#   converged_iterations: 17
#   expected_initial_state_value: 6.367867097536757
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.367867097536754
#   mc_success_rate: 1.0
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.36787
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.36787
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.09857
# wandb:
# wandb: 🚀 View run taxi_pi_seed0 13/12-16:59:17 at: https://wandb.ai/fatty_data/CVI-RL/runs/s2df513z
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_165917-s2df513z/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.36787
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.36787
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.09857
# wandb:
# wandb: 🚀 View run taxi_pi_seed0 13/12-16:59:17 at: https://wandb.ai/fatty_data/CVI-RL/runs/s2df513z
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_165917-s2df513z/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on taxi with seed 0
#
# Progress: 1/24 completed (0 failed)
# ✅ Completed: pi on taxi with seed 0
#
# Progress: 1/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: pi on taxi with seed 42
# ============================================================
# Command: python train.py config/taxi_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_pi_seed42 logger.tags="['algo_pi','env_taxi','seed_42']" seed=42
#
#
# ============================================================
# 🚀 Running: pi on taxi with seed 42
# ============================================================
# Command: python train.py config/taxi_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_pi_seed42 logger.tags="['algo_pi','env_taxi','seed_42']" seed=42
#
# Random seed set to: 42
# Random seed set to: 42
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_165957-zs7r0pqs
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed42 13/12-16:59:56
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/zs7r0pqs
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_165957-zs7r0pqs
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed42 13/12-16:59:56
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/zs7r0pqs
# W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:   0%|                                  | 0/50 [00:00<?, ?it/s]W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:56,  1.65s/it]
# First Evaluation: -99.99990136574544
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 14436.24it/s]
#
# Converged in 17 iterations
# Training time: 26.47s
# Policy saved to saved_policies/pi_taxi_policy.npy
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:56,  1.65s/it]
# First Evaluation: -99.99990136574544
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 14436.24it/s]
#
# Converged in 17 iterations
# Training time: 26.47s
# Policy saved to saved_policies/pi_taxi_policy.npy
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.469257831573486
#   converged_iterations: 17
#   expected_initial_state_value: 6.505104355682094
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.505104355682091
#   mc_success_rate: 1.0
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.469257831573486
#   converged_iterations: 17
#   expected_initial_state_value: 6.505104355682094
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.505104355682091
#   mc_success_rate: 1.0
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.5051
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.5051
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.46926
# wandb:
# wandb: 🚀 View run taxi_pi_seed42 13/12-16:59:56 at: https://wandb.ai/fatty_data/CVI-RL/runs/zs7r0pqs
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_165957-zs7r0pqs/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.5051
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.5051
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.46926
# wandb:
# wandb: 🚀 View run taxi_pi_seed42 13/12-16:59:56 at: https://wandb.ai/fatty_data/CVI-RL/runs/zs7r0pqs
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_165957-zs7r0pqs/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on taxi with seed 42
#
# Progress: 2/24 completed (0 failed)
# ✅ Completed: pi on taxi with seed 42
#
# Progress: 2/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: pi on taxi with seed 100
# ============================================================
# Command: python train.py config/taxi_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_pi_seed100 logger.tags="['algo_pi','env_taxi','seed_100']" seed=100
#
#
# ============================================================
# 🚀 Running: pi on taxi with seed 100
# ============================================================
# Command: python train.py config/taxi_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_pi_seed100 logger.tags="['algo_pi','env_taxi','seed_100']" seed=100
#
# Random seed set to: 100
# Random seed set to: 100
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170035-yzc8of1s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed100 13/12-17:00:34
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/yzc8of1s
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170035-yzc8of1s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_pi_seed100 13/12-17:00:34
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/yzc8of1s
# W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:   0%|                                  | 0/50 [00:00<?, ?it/s]W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 50
#   Gamma: 0.99
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:56,  1.65s/it]
# First Evaluation: -99.99990136574544
# Policy Iteration:  32%|████████                 | 16/50 [00:26<00:56,  1.65s/it]
# First Evaluation: -99.99990136574544
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 13844.42it/s]
#
# Converged in 17 iterations
# Training time: 26.41s
# Policy saved to saved_policies/pi_taxi_policy.npy
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 13844.42it/s]
#
# Converged in 17 iterations
# Training time: 26.41s
# Policy saved to saved_policies/pi_taxi_policy.npy
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.408014059066772
#   converged_iterations: 17
#   expected_initial_state_value: 6.506176659139016
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.506176659139014
#   mc_success_rate: 1.0
# Policy uploaded to W&B as artifact: pi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 26.408014059066772
#   converged_iterations: 17
#   expected_initial_state_value: 6.506176659139016
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.506176659139014
#   mc_success_rate: 1.0
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.50618
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.50618
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.40801
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▄▅▆▇▇▇████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 17
# wandb: expected_initial_state_value 6.50618
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.50618
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 26.40801
# wandb:
# wandb: 🚀 View run taxi_pi_seed100 13/12-17:00:34 at: https://wandb.ai/fatty_data/CVI-RL/runs/yzc8of1s
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170035-yzc8of1s/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb: 🚀 View run taxi_pi_seed100 13/12-17:00:34 at: https://wandb.ai/fatty_data/CVI-RL/runs/yzc8of1s
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170035-yzc8of1s/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on taxi with seed 100
#
# Progress: 3/24 completed (0 failed)
# ✅ Completed: pi on taxi with seed 100
#
# Progress: 3/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 0
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed0 logger.tags="['algo_pi','env_frozenlake','seed_0']" seed=0
#
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 0
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed0 logger.tags="['algo_pi','env_frozenlake','seed_0']" seed=0
#
# Random seed set to: 0
# Random seed set to: 0
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170112-65adujxi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed0 13/12-17:01:12
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/65adujxi
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170112-65adujxi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed0 13/12-17:01:12
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/65adujxi
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                                | 0/5000 [00:00<?, ?it/s]W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:04, 20.43it/s]
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:04, 20.43it/s]
# First Evaluation: 0.009545453902765049
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4154.59it/s]
#
# Converged in 11 iterations
# Training time: 0.54s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
# First Evaluation: 0.009545453902765049
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4154.59it/s]
#
# Converged in 11 iterations
# Training time: 0.54s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5440101623535156
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.3541253922676305
#   mc_success_rate: 0.63
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5440101623535156
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.3541253922676305
#   mc_success_rate: 0.63
# wandb:
# wandb: W&B sync reduced upload amount by 19.9%
# wandb:
# wandb: W&B sync reduced upload amount by 19.9%
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.35413
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.54401
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed0 13/12-17:01:12 at: https://wandb.ai/fatty_data/CVI-RL/runs/65adujxi
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170112-65adujxi/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.35413
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.54401
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed0 13/12-17:01:12 at: https://wandb.ai/fatty_data/CVI-RL/runs/65adujxi
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170112-65adujxi/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on frozenlake with seed 0
#
# Progress: 4/24 completed (0 failed)
# ✅ Completed: pi on frozenlake with seed 0
#
# Progress: 4/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 42
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed42 logger.tags="['algo_pi','env_frozenlake','seed_42']" seed=42
#
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 42
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed42 logger.tags="['algo_pi','env_frozenlake','seed_42']" seed=42
#
# Random seed set to: 42
# Random seed set to: 42
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170129-jjehw77b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed42 13/12-17:01:29
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/jjehw77b
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170129-jjehw77b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed42 13/12-17:01:29
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/jjehw77b
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                                | 0/5000 [00:00<?, ?it/s]W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:06, 20.21it/s]
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:06, 20.21it/s]
# First Evaluation: 0.009545453902765049
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4038.93it/s]
# First Evaluation: 0.009545453902765049
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4038.93it/s]
#
# Converged in 11 iterations
# Training time: 0.55s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
#
# Converged in 11 iterations
# Training time: 0.55s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5502579212188721
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.3318690130053002
#   mc_success_rate: 0.63
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5502579212188721
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.3318690130053002
#   mc_success_rate: 0.63
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.33187
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.55026
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed42 13/12-17:01:29 at: https://wandb.ai/fatty_data/CVI-RL/runs/jjehw77b
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170129-jjehw77b/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.33187
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.55026
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed42 13/12-17:01:29 at: https://wandb.ai/fatty_data/CVI-RL/runs/jjehw77b
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170129-jjehw77b/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on frozenlake with seed 42
#
# Progress: 5/24 completed (0 failed)
# ✅ Completed: pi on frozenlake with seed 42
#
# Progress: 5/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 100
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed100 logger.tags="['algo_pi','env_frozenlake','seed_100']" seed=100
#
#
# ============================================================
# 🚀 Running: pi on frozenlake with seed 100
# ============================================================
# Command: python train.py config/frozenlake_pi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_pi_seed100 logger.tags="['algo_pi','env_frozenlake','seed_100']" seed=100
#
# Random seed set to: 100
# Random seed set to: 100
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170144-7x5nyh5w
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed100 13/12-17:01:43
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/7x5nyh5w
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170144-7x5nyh5w
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_pi_seed100 13/12-17:01:43
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/7x5nyh5w
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                                | 0/5000 [00:00<?, ?it/s]W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Policy Iteration
# ============================================================
#   Policy eval termination: 1e-6
#   Max policy iterations: 5000
#   Gamma: 0.99
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:01, 20.64it/s]
# Policy Iteration:   0%|                       | 10/5000 [00:00<04:01, 20.64it/s]
# First Evaluation: 0.009545453902765049
# MC Evaluation:   0%|                                    | 0/100 [00:00<?, ?it/s]First Evaluation: 0.009545453902765049
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4061.22it/s]
#
# Converged in 11 iterations
# Training time: 0.55s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4061.22it/s]
#
# Converged in 11 iterations
# Training time: 0.55s
# Policy saved to saved_policies/pi_frozenlake-8x8_policy.npy
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5480310916900635
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.317197800849211
#   mc_success_rate: 0.57
# Policy uploaded to W&B as artifact: pi_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.5480310916900635
#   converged_iterations: 11
#   expected_initial_state_value: 0.4146334795938332
#   final_mean_v_value: 0.33700207029248563
#   mc_avg_return: 0.317197800849211
#   mc_success_rate: 0.57
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.3172
# wandb:              mc_success_rate 0.57
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.54803
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed100 13/12-17:01:43 at: https://wandb.ai/fatty_data/CVI-RL/runs/7x5nyh5w
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170144-7x5nyh5w/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 11
# wandb: expected_initial_state_value 0.41463
# wandb:           final_mean_v_value 0.337
# wandb:                mc_avg_return 0.3172
# wandb:              mc_success_rate 0.57
# wandb:                 mean_v_value 0.337
# wandb:                training_time 0.54803
# wandb:
# wandb: 🚀 View run frozenlake_pi_seed100 13/12-17:01:43 at: https://wandb.ai/fatty_data/CVI-RL/runs/7x5nyh5w
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170144-7x5nyh5w/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: pi on frozenlake with seed 100
#
# Progress: 6/24 completed (0 failed)
# ✅ Completed: pi on frozenlake with seed 100
#
# Progress: 6/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: vi on taxi with seed 0
# ============================================================
# Command: python train.py config/taxi_vi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_vi_seed0 logger.tags="['algo_vi','env_taxi','seed_0']" seed=0
#
#
# ============================================================
# 🚀 Running: vi on taxi with seed 0
# ============================================================
# Command: python train.py config/taxi_vi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_vi_seed0 logger.tags="['algo_vi','env_taxi','seed_0']" seed=0
#
# Random seed set to: 0
# Random seed set to: 0
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170158-wjashbjp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_vi_seed0 13/12-17:01:57
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/wjashbjp
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170158-wjashbjp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_vi_seed0 13/12-17:01:57
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/wjashbjp
# W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Value Iteration
# ============================================================
#   Value iteration termination: 1e-6
#   Max value iteration iterations: 50
#   Gamma: 0.99
# W&B logging enabled: CVI-RL
#
# Initializing environment: taxi
#
# ============================================================
# Running Value Iteration
# ============================================================
#   Value iteration termination: 1e-6
#   Max value iteration iterations: 50
#   Gamma: 0.99
# First Evaluation: 0.0
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 12758.34it/s]
#
# Converged in 13 iterations
# Training time: 0.02s
# Policy saved to saved_policies/vi_taxi_policy.npy
# First Evaluation: 0.0
# MC Evaluation: 100%|███████████████████████| 100/100 [00:00<00:00, 12758.34it/s]
#
# Converged in 13 iterations
# Training time: 0.02s
# Policy saved to saved_policies/vi_taxi_policy.npy
# Policy uploaded to W&B as artifact: vi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.01543116569519043
#   converged_iterations: 13
#   expected_initial_state_value: 6.3499591313791015
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.3499591313791
#   mc_success_rate: 1.0
# Policy uploaded to W&B as artifact: vi_taxi_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 0.01543116569519043
#   converged_iterations: 13
#   expected_initial_state_value: 6.3499591313791015
#   final_mean_v_value: 9.422837256540403
#   mc_avg_return: 6.3499591313791
#   mc_success_rate: 1.0
# wandb:
# wandb: W&B sync reduced upload amount by 21.7%
# wandb:
# wandb: W&B sync reduced upload amount by 21.7%
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▅▆▇███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 13
# wandb: expected_initial_state_value 6.34996
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.34996
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 0.01543
# wandb:
# wandb: 🚀 View run taxi_vi_seed0 13/12-17:01:57 at: https://wandb.ai/fatty_data/CVI-RL/runs/wjashbjp
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170158-wjashbjp/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▁▂▂▃▄▅▆▇███
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 13
# wandb: expected_initial_state_value 6.34996
# wandb:           final_mean_v_value 9.42284
# wandb:                mc_avg_return 6.34996
# wandb:              mc_success_rate 1.0
# wandb:                 mean_v_value 9.42284
# wandb:                training_time 0.01543
# wandb:
# wandb: 🚀 View run taxi_vi_seed0 13/12-17:01:57 at: https://wandb.ai/fatty_data/CVI-RL/runs/wjashbjp
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170158-wjashbjp/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: vi on taxi with seed 0
#
# Progress: 7/24 completed (0 failed)
# ✅ Completed: vi on taxi with seed 0
#
# Progress: 7/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: vi on taxi with seed 42
# ============================================================
# Command: python train.py config/taxi_vi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_vi_seed42 logger.tags="['algo_vi','env_taxi','seed_42']" seed=42
#
#
# ============================================================
# 🚀 Running: vi on taxi with seed 42
# ============================================================
# Command: python train.py config/taxi_vi.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=taxi_vi_seed42 logger.tags="['algo_vi','env_taxi','seed_42']" seed=42
#
# Random seed set to: 42
# Random seed set to: 42
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170210-d2nx3lks
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run taxi_vi_seed42 13/12-17:02:09
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/d2nx3lks
# wandb: Tracking run with wandb version 0.17.9
# ...
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.35585
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.28201
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.35585
# wandb:              mc_success_rate 0.63
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.28201
# wandb:
# wandb: 🚀 View run frozenlake_c51_seed0 13/12-17:09:32 at: https://wandb.ai/fatty_data/CVI-RL/runs/gmesv8bo
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170933-gmesv8bo/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb: 🚀 View run frozenlake_c51_seed0 13/12-17:09:32 at: https://wandb.ai/fatty_data/CVI-RL/runs/gmesv8bo
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170933-gmesv8bo/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: c51 on frozenlake with seed 0
#
# Progress: 22/24 completed (0 failed)
# ✅ Completed: c51 on frozenlake with seed 0
#
# Progress: 22/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: c51 on frozenlake with seed 42
# ============================================================
# Command: python train.py config/frozenlake_c51.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_c51_seed42 logger.tags="['algo_c51','env_frozenlake','seed_42']" seed=42
#
#
# ============================================================
# 🚀 Running: c51 on frozenlake with seed 42
# ============================================================
# Command: python train.py config/frozenlake_c51.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_c51_seed42 logger.tags="['algo_c51','env_frozenlake','seed_42']" seed=42
#
# Random seed set to: 42
# Random seed set to: 42
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170952-yh5d05fa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_c51_seed42 13/12-17:09:51
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/yh5d05fa
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_170952-yh5d05fa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_c51_seed42 13/12-17:09:51
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/yh5d05fa
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Tabular C51 (Categorical Distributional VI)
# ============================================================
#   Gamma: 0.99
#   Support: [-5.0, 5.0] with n_atoms=51
#   Max iters: 1000, eps: 1e-06
#
# ============================================================
# Running Tabular C51 (Categorical Distributional VI)
# ============================================================
#   Gamma: 0.99
#   Support: [-5.0, 5.0] with n_atoms=51
#   Max iters: 1000, eps: 1e-06
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4023.16it/s]
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 4023.16it/s]
# Policy saved to saved_policies/c51_frozenlake-8x8_policy.npy
# Policy saved to saved_policies/c51_frozenlake-8x8_policy.npy
# Policy uploaded to W&B as artifact: c51_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 6.330074071884155
#   converged_iterations: 442
#   expected_initial_state_value: 0.41463905822440283
#   final_mean_v_value: 0.33700513395935827
#   mc_avg_return: 0.33206188238643164
#   mc_success_rate: 0.61
# Policy uploaded to W&B as artifact: c51_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 6.330074071884155
#   converged_iterations: 442
#   expected_initial_state_value: 0.41463905822440283
#   final_mean_v_value: 0.33700513395935827
#   mc_avg_return: 0.33206188238643164
#   mc_success_rate: 0.61
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.33206
# wandb:              mc_success_rate 0.61
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.33007
# wandb:
# wandb: 🚀 View run frozenlake_c51_seed42 13/12-17:09:51 at: https://wandb.ai/fatty_data/CVI-RL/runs/yh5d05fa
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170952-yh5d05fa/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.33206
# wandb:              mc_success_rate 0.61
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.33007
# wandb:
# wandb: 🚀 View run frozenlake_c51_seed42 13/12-17:09:51 at: https://wandb.ai/fatty_data/CVI-RL/runs/yh5d05fa
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_170952-yh5d05fa/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: c51 on frozenlake with seed 42
#
# Progress: 23/24 completed (0 failed)
# ✅ Completed: c51 on frozenlake with seed 42
#
# Progress: 23/24 completed (0 failed)
#
# ============================================================
# 🚀 Running: c51 on frozenlake with seed 100
# ============================================================
# Command: python train.py config/frozenlake_c51.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_c51_seed100 logger.tags="['algo_c51','env_frozenlake','seed_100']" seed=100
#
#
# ============================================================
# 🚀 Running: c51 on frozenlake with seed 100
# ============================================================
# Command: python train.py config/frozenlake_c51.yaml logger.do.online=true logger.project_name=CVI-RL logger.run_name=frozenlake_c51_seed100 logger.tags="['algo_c51','env_frozenlake','seed_100']" seed=100
#
# Random seed set to: 100
# Random seed set to: 100
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Currently logged in as: thom-mousseau (fatty_data). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_171010-mrpqsp28
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_c51_seed100 13/12-17:10:09
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/mrpqsp28
# wandb: Tracking run with wandb version 0.17.9
# wandb: Run data is saved locally in /Users/thomasmousseau/School/Maitrise/RL/CVI/wandb/run-20251213_171010-mrpqsp28
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frozenlake_c51_seed100 13/12-17:10:09
# wandb: ⭐️ View project at https://wandb.ai/fatty_data/CVI-RL
# wandb: 🚀 View run at https://wandb.ai/fatty_data/CVI-RL/runs/mrpqsp28
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
# W&B logging enabled: CVI-RL
#
# Initializing environment: frozenlake-8x8
#
# ============================================================
# Running Tabular C51 (Categorical Distributional VI)
# ============================================================
#   Gamma: 0.99
#   Support: [-5.0, 5.0] with n_atoms=51
#   Max iters: 1000, eps: 1e-06
#
# ============================================================
# Running Tabular C51 (Categorical Distributional VI)
# ============================================================
#   Gamma: 0.99
#   Support: [-5.0, 5.0] with n_atoms=51
#   Max iters: 1000, eps: 1e-06
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 3876.26it/s]
# MC Evaluation: 100%|████████████████████████| 100/100 [00:00<00:00, 3876.26it/s]
# Policy saved to saved_policies/c51_frozenlake-8x8_policy.npyPolicy saved to saved_policies/c51_frozenlake-8x8_policy.npy
#
# Policy uploaded to W&B as artifact: c51_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 6.329264163970947
#   converged_iterations: 442
#   expected_initial_state_value: 0.41463905822440283
#   final_mean_v_value: 0.33700513395935827
#   mc_avg_return: 0.35093491132675175
#   mc_success_rate: 0.64
# Policy uploaded to W&B as artifact: c51_frozenlake-8x8_policy
#
# ============================================================
# Training completed successfully!
# ============================================================
#
# Final Metrics:
#   training_time: 6.329264163970947
#   converged_iterations: 442
#   expected_initial_state_value: 0.41463905822440283
#   final_mean_v_value: 0.33700513395935827
#   mc_avg_return: 0.35093491132675175
#   mc_success_rate: 0.64
# wandb:
# wandb:
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.35093
# wandb:              mc_success_rate 0.64
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.32926
# wandb:
# wandb: 🚀 View run frozenlake_c51_seed100 13/12-17:10:09 at: https://wandb.ai/fatty_data/CVI-RL/runs/mrpqsp28
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_171010-mrpqsp28/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# wandb:
# wandb: Run history:
# wandb:         converged_iterations ▁
# wandb: expected_initial_state_value ▁
# wandb:           final_mean_v_value ▁
# wandb:                mc_avg_return ▁
# wandb:              mc_success_rate ▁
# wandb:                 mean_v_value ▁▂▃▄▅▅▆▇▇▇▇█████████████████████████████
# wandb:                training_time ▁
# wandb:
# wandb: Run summary:
# wandb:         converged_iterations 442
# wandb: expected_initial_state_value 0.41464
# wandb:           final_mean_v_value 0.33701
# wandb:                mc_avg_return 0.35093
# wandb:              mc_success_rate 0.64
# wandb:                 mean_v_value 0.33701
# wandb:                training_time 6.32926
# wandb:
# wandb: 🚀 View run frozenlake_c51_seed100 13/12-17:10:09 at: https://wandb.ai/fatty_data/CVI-RL/runs/mrpqsp28
# wandb: ⭐️ View project at: https://wandb.ai/fatty_data/CVI-RL
# wandb: Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251213_171010-mrpqsp28/logs
# wandb: WARNING wandb version 0.23.1 is available!  To upgrade, please run:
# wandb: WARNING  $ pip install wandb --upgrade
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ✅ Completed: c51 on frozenlake with seed 100
#
# Progress: 24/24 completed (0 failed)
# ✅ Completed: c51 on frozenlake with seed 100
#
# Progress: 24/24 completed (0 failed)
#
# ============================================================
# All experiments completed!
# Total time: 11.22 minutes
# Successful: 24/24
# Failed: 0/24
# ============================================================
#
# ============================================================
# All experiments completed!
# Total time: 11.22 minutes
# Successful: 24/24
# Failed: 0/24
# ============================================================
